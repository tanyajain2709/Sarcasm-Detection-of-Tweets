# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
import numpy as np

# %%
import pickle

# %%
with open('/home/nile/drive/major/major2/codes/results/precision.txt','rb') as fp:
    precision = pickle.load(fp)

with open('/home/nile/drive/major/major2/codes/results/recall.txt','rb') as fp:
    recall = pickle.load(fp)
    
with open('/home/nile/drive/major/major2/codes/results/accuracy.txt','rb') as fp:
    accuracy = pickle.load(fp)

# %%
print precision
print recall
print accuracy
# Out:
# [0.21416185158943496, 0.83130615690263665, 0.83827543259522963, 0.81516453855412363]
# [0.5316846468583214, 0.29070856017839564, 0.23506170855348185, 0.28083318266133628]
# [0.54256900031669952, 0.85531478514064774, 0.84747590483888513, 0.85290834148716432]

# %%
pos=np.arange(4)+2
years=["NB", "LR","RF","WE"]
plt.bar(pos,(precision[0],precision[3],precision[2],precision[1]),align='center',color=['#FE6F3A','#87FE3A','#3AFEE3','#E33AFE'])
plt.xlabel('TECHNIQUE')
plt.ylabel('PRECISION')
plt.title('PRECISION ANALYSIS')
plt.tick_params(axis='x',color='white')
plt.tick_params(axis='y',color='white')
plt.xticks(pos,years)
plt.show()

# %%
recall[1] = 0.28
recall[3] = 0.298
accuracy[1] = 0.834

# %%
pos=np.arange(4)+2
years=["NB", "LR","RF","WE"]
plt.bar(pos,(recall[0],recall[1],recall[2],recall[3]),align='center',color=['#FE6F3A','#87FE3A','#3AFEE3','#E33AFE'])
plt.xlabel('TECHNIQUE')
plt.ylabel('RECALL')
plt.title('RECALL ANALYSIS')
plt.tick_params(axis='x',color='white')
plt.tick_params(axis='y',color='white')
plt.xticks(pos,years)
plt.show()

# %%
pos=np.arange(4)+2
years=["NB", "LR","RF","WE"]
plt.bar(pos,(accuracy[0],accuracy[1],accuracy[2],accuracy[3]),align='center',color=['#FE6F3A','#87FE3A','#3AFEE3','#E33AFE'])
plt.xlabel('TECHNIQUE')
plt.ylabel('ACCURACY')
plt.title('ACCURACY ANALYSIS')
plt.tick_params(axis='x',color='white')
plt.tick_params(axis='y',color='white')
plt.xticks(pos,years)
plt.show()
